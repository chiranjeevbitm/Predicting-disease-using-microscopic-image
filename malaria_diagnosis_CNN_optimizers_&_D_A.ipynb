# %%
# #to access kaggle datasets
# !pip install kaggle
# #Math operations
# !pip install numpy
# #Machine learning

# %%
#data preprocessing
import pandas as pd
#math operations
import numpy as np
#machine learning
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import os
import cv2
import keras
from keras.utils import np_utils
# from keras.models import Sequential
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

from tensorflow.keras.models import load_model


from random import shuffle
from tqdm import tqdm  
import scipy
import skimage
from skimage.transform import resize
import random
# Out:
# Using TensorFlow backend.

# %%
PARA_DIR = 'cell_images/Parasitized'
UNIF_DIR = 'cell_images/Uninfected'

# %%
Pimages = os.listdir(PARA_DIR)
Nimages = os.listdir(UNIF_DIR)

# %%
sample_normal = random.sample(Nimages,6)
f,ax = plt.subplots(2,3,figsize=(15,9))

for i in range(0,6):
    im = cv2.imread('cell_images/Uninfected/'+sample_normal[i])
    ax[i//3,i%3].imshow(im)
    ax[i//3,i%3].axis('off')
f.suptitle('Uninfected')
plt.show()

# %%
sample_parasite = random.sample(Pimages,6)
f,ax = plt.subplots(2,3,figsize=(15,9))

for i in range(0,6):
    im = cv2.imread('cell_images/Parasitized/'+sample_parasite[i])
    ax[i//3,i%3].imshow(im)
    ax[i//3,i%3].axis('off')
f.suptitle('Parasitized')
plt.show()

# %%
# %%time
data=[]
labels=[]
Parasitized=os.listdir("cell_images/Parasitized/")
for a in Parasitized:
    try:
        image=cv2.imread("cell_images/Parasitized/"+a)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((125, 125))
        data.append(np.array(size_image))
        labels.append(0)
    except AttributeError:
        print("")

Uninfected=os.listdir("cell_images/Uninfected/")
for b in Uninfected:
    try:
        image=cv2.imread("cell_images/Uninfected/"+b)
        image_from_array = Image.fromarray(image, 'RGB')
        size_image = image_from_array.resize((125, 125))
        data.append(np.array(size_image))
        labels.append(1)
    except AttributeError:
        print("")
# Out:
# CPU times: user 30 s, sys: 13.1 s, total: 43.1 s
# Wall time: 1min 18s

# %%
# %%time
Cells=np.array(data)
labels=np.array(labels)
# Out:
# CPU times: user 791 ms, sys: 1.62 s, total: 2.41 s
# Wall time: 3.23 s

# %%
np.save("Cells",Cells)
np.save("labels",labels)

# %%
Cells=np.load("Cells.npy")
labels=np.load("labels.npy")

# %%
s=np.arange(Cells.shape[0])
np.random.shuffle(s)
Cells=Cells[s]
labels=labels[s]

# %%
num_classes=len(np.unique(labels))
len_data=len(Cells)

# %%
# %%time
(x_train,x_test)=Cells[(int)(0.1*len_data):],Cells[:(int)(0.1*len_data)]
x_train = x_train.astype('float32')/255 # As we are working on image data we are normalizing data by divinding 255.
x_test = x_test.astype('float32')/255
train_len=len(x_train)
test_len=len(x_test)
# Out:
# CPU times: user 4.14 s, sys: 11.3 s, total: 15.4 s
# Wall time: 21.5 s

# %%
(y_train,y_test)=labels[(int)(0.1*len_data):],labels[:(int)(0.1*len_data)]

# %%
#Doing One hot encoding as classifier has multiple classes
y_train=keras.utils.to_categorical(y_train,num_classes)
y_test=keras.utils.to_categorical(y_test,num_classes)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

# Set random seed
np.random.seed(0)

# %%
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.layers import BatchNormalization
import keras
from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras import backend as K

from tensorflow.keras import optimizers

# %%
def CNNbuild(height, width, classes, channels):
    model = Sequential()
    
    inputShape = (height, width, channels)
    chanDim = -1
    
    if K.image_data_format() == 'channels_first':
        inputShape = (channels, height, width)
    model.add(Conv2D(32, (3,3), activation = 'relu', input_shape = inputShape))
    model.add(MaxPooling2D(2,2))
    model.add(BatchNormalization(axis = chanDim))
    model.add(Dropout(0.2))

    model.add(Conv2D(32, (3,3), activation = 'relu'))
    model.add(MaxPooling2D(2,2))
    model.add(BatchNormalization(axis = chanDim))
    model.add(Dropout(0.2))

    model.add(Conv2D(32, (3,3), activation = 'relu'))
    model.add(MaxPooling2D(2,2))
    model.add(BatchNormalization(axis = chanDim))
    model.add(Dropout(0.2))

    model.add(Flatten())
    
    model.add(Dense(512, activation = 'relu'))
    model.add(BatchNormalization(axis = chanDim))
    model.add(Dropout(0.5))
    model.add(Dense(classes, activation = 'softmax'))
    
    return model

# %%
#instantiate the model
height = 125
width = 125
classes = 2
channels = 3
model = CNNbuild(height = height, width = width, classes = classes, channels = channels)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 123, 123, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 61, 61, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 61, 61, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 61, 61, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 59, 59, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 29, 29, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 29, 29, 32)        128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 29, 29, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 27, 27, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 13, 13, 32)        128
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 5408)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2769408
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 2,792,258
# Trainable params: 2,791,042
# Non-trainable params: 1,216
# _________________________________________________________________

# %%
import tensorflow as tf

# Load the TensorBoard notebook extension (optional)
# %load_ext tensorboard

# tf.random.set_seed(42)
tf.__version__
# Out:
# '2.0.1'

# %%
BATCH_SIZE = 32
NUM_CLASSES = 2
EPOCHS = 25
INPUT_SHAPE = (125, 125, 3)

# %%
# %%time
import datetime

logdir = os.path.join('tensorboard_logs', 
                      datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=2, min_lr=0.0005)


callbacks = [reduce_lr, tensorboard_callback]
# Out:
# CPU times: user 116 µs, sys: 157 µs, total: 273 µs
# Wall time: 282 µs

# %% [markdown]
# # Model ADAM

# %%
# %%time
#compile the model
model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])
history = model.fit(x=x_train, y=y_train, 
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS, 
                    validation_data=(x_test, y_test), 
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Train on 24664 samples, validate on 2740 samples
# Epoch 1/25
# 24664/24664 [==============================] - 465s 19ms/sample - loss: 0.5144 - accuracy: 0.7846 - val_loss: 0.6436 - val_accuracy: 0.7982
# Epoch 2/25
# 24664/24664 [==============================] - 450s 18ms/sample - loss: 0.2281 - accuracy: 0.9205 - val_loss: 0.2735 - val_accuracy: 0.9099
# Epoch 3/25
# 24664/24664 [==============================] - 447s 18ms/sample - loss: 0.1849 - accuracy: 0.9383 - val_loss: 0.2420 - val_accuracy: 0.9172
# Epoch 4/25
# 24664/24664 [==============================] - 448s 18ms/sample - loss: 0.1674 - accuracy: 0.9432 - val_loss: 0.3102 - val_accuracy: 0.8996
# Epoch 5/25
# 24664/24664 [==============================] - 453s 18ms/sample - loss: 0.1517 - accuracy: 0.9486 - val_loss: 0.1918 - val_accuracy: 0.9296
# Epoch 6/25
# 24664/24664 [==============================] - 451s 18ms/sample - loss: 0.1489 - accuracy: 0.9500 - val_loss: 0.1706 - val_accuracy: 0.9380
# Epoch 7/25
# 24664/24664 [==============================] - 449s 18ms/sample - loss: 0.1379 - accuracy: 0.9532 - val_loss: 0.1854 - val_accuracy: 0.9442
# Epoch 8/25
# 24664/24664 [==============================] - 453s 18ms/sample - loss: 0.1300 - accuracy: 0.9542 - val_loss: 0.2072 - val_accuracy: 0.9420
# Epoch 9/25
# 24664/24664 [==============================] - 452s 18ms/sample - loss: 0.1196 - accuracy: 0.9588 - val_loss: 0.1317 - val_accuracy: 0.9569
# Epoch 10/25
# 24664/24664 [==============================] - 447s 18ms/sample - loss: 0.1099 - accuracy: 0.9616 - val_loss: 0.1441 - val_accuracy: 0.9551
# Epoch 11/25
# 24664/24664 [==============================] - 446s 18ms/sample - loss: 0.1023 - accuracy: 0.9645 - val_loss: 0.1333 - val_accuracy: 0.9573
# Epoch 12/25
# 24664/24664 [==============================] - 449s 18ms/sample - loss: 0.1009 - accuracy: 0.9655 - val_loss: 0.1462 - val_accuracy: 0.9511
# Epoch 13/25
# 24664/24664 [==============================] - 453s 18ms/sample - loss: 0.1002 - accuracy: 0.9657 - val_loss: 0.1466 - val_accuracy: 0.9558
# Epoch 14/25
# 24664/24664 [==============================] - 451s 18ms/sample - loss: 0.0897 - accuracy: 0.9683 - val_loss: 0.1322 - val_accuracy: 0.9529
# Epoch 15/25
# 24664/24664 [==============================] - 454s 18ms/sample - loss: 0.0894 - accuracy: 0.9689 - val_loss: 0.1397 - val_accuracy: 0.9518
# Epoch 16/25
# 24664/24664 [==============================] - 458s 19ms/sample - loss: 0.0832 - accuracy: 0.9723 - val_loss: 0.1354 - val_accuracy: 0.9515
# Epoch 17/25
# 24664/24664 [==============================] - 456s 18ms/sample - loss: 0.0749 - accuracy: 0.9737 - val_loss: 0.1492 - val_accuracy: 0.9551
# Epoch 18/25
# 24664/24664 [==============================] - 515s 21ms/sample - loss: 0.0742 - accuracy: 0.9746 - val_loss: 0.1497 - val_accuracy: 0.9558
# Epoch 19/25
# 24664/24664 [==============================] - 469s 19ms/sample - loss: 0.0668 - accuracy: 0.9777 - val_loss: 0.1530 - val_accuracy: 0.9526
# Epoch 20/25
# 24664/24664 [==============================] - 451s 18ms/sample - loss: 0.0630 - accuracy: 0.9780 - val_loss: 0.1486 - val_accuracy: 0.9482
# Epoch 21/25
# 24664/24664 [==============================] - 1408s 57ms/sample - loss: 0.0638 - accuracy: 0.9787 - val_loss: 0.1491 - val_accuracy: 0.9566
# Epoch 22/25
# 24664/24664 [==============================] - 448s 18ms/sample - loss: 0.0571 - accuracy: 0.9802 - val_loss: 0.1647 - val_accuracy: 0.9504
# Epoch 23/25
# 24664/24664 [==============================] - 444s 18ms/sample - loss: 0.0573 - accuracy: 0.9803 - val_loss: 0.1557 - val_accuracy: 0.9522
# Epoch 24/25
# 24664/24664 [==============================] - 443s 18ms/sample - loss: 0.0538 - accuracy: 0.9805 - val_loss: 0.1582 - val_accuracy: 0.9507
# Epoch 25/25
# 24664/24664 [==============================] - 443s 18ms/sample - loss: 0.0502 - accuracy: 0.9821 - val_loss: 0.1605 - val_accuracy: 0.9485
# CPU times: user 7h 46min 35s, sys: 1h 56min 50s, total: 9h 43min 26s
# Wall time: 3h 25min 5s

# %%
from sklearn.metrics import accuracy_score
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 10))
t = f.suptitle('Basic CNN Performance', fontsize=16,fontweight='bold')
f.subplots_adjust(top=0.9, wspace=0.1)

max_epoch = len(history.history['accuracy'])+1
epoch_list = list(range(1,max_epoch))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(1, max_epoch, 1))
ax1.set_ylabel('Accuracy Value',fontsize=14,fontweight='bold')
ax1.set_xlabel('Epoch',fontsize=14,fontweight='bold')
ax1.set_title('Accuracy', fontsize=14,fontweight='bold')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(1, max_epoch, 1))
ax2.set_ylabel('Loss Value',fontsize=14,fontweight='bold')
ax2.set_xlabel('Epoch',fontsize=14,fontweight='bold')
ax2.set_title('Loss',fontsize=14,fontweight='bold')
l2 = ax2.legend(loc="best")

# %%
## Loading tensorboard
# import tensorflow as tf
# from tensorflow.python.summary import summary_iterator
# import os
# log_base_dir = 'Desktop/tensorboard_logs'
# os.makedirs(log_base_dir,exist_ok = True)
# %tensorboard --logdir {log_base_dir}

# %%
# from numpy import loadtxt
# from keras.models import load_model
# model = load_model('.mdl_wts.hdf5')

# %%
from sklearn.metrics import confusion_matrix
pred = model.predict(x_test)
pred = np.argmax(pred,axis = 1) 
y_true = np.argmax(y_test,axis = 1)

# %%
# %%time
import mlxtend
CM = confusion_matrix(y_true, pred)
from mlxtend.plotting import plot_confusion_matrix
fig, ax = plot_confusion_matrix(conf_mat=CM ,  figsize=(5, 5))
plt.show()
# Out:
# CPU times: user 304 ms, sys: 40 ms, total: 344 ms
# Wall time: 212 ms

# %%
#model.save('models_app/my_model.h5')

# %%
x_test.shape[0]
# Out:
# 2740

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Accuracy")
plt.ylabel("Epochs")
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
from sklearn.metrics import auc
fpr_keras, tpr_keras, thresholds = roc_curve(y_true.ravel(), pred.ravel())
auc_keras = auc(fpr_keras, tpr_keras)

# %%
def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color='orange', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()

# %%
plot_roc_curve(fpr_keras, tpr_keras)

# %%
from sklearn.metrics import classification_report

# %%
print('{}'.format(classification_report(y_true , pred)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95      1351
#            1       0.93      0.97      0.95      1389
#
#     accuracy                           0.95      2740
#    macro avg       0.95      0.95      0.95      2740
# weighted avg       0.95      0.95      0.95      2740

# %% [markdown]
# # Model 2 SGD

# %%
#instantiate the model
height = 125
width = 125
classes = 2
channels = 3
model2 = CNNbuild(height = height, width = width, classes = classes, channels = channels)
model2.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 123, 123, 32)      896
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 61, 61, 32)        0
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 61, 61, 32)        128
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 61, 61, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 59, 59, 32)        9248
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 29, 29, 32)        0
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 29, 29, 32)        128
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 29, 29, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 27, 27, 32)        9248
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 13, 13, 32)        128
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 5408)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               2769408
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 2,792,258
# Trainable params: 2,791,042
# Non-trainable params: 1,216
# _________________________________________________________________

# %%
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model2.compile( loss = "categorical_crossentropy", 
               optimizer = sgd, 
               metrics=['accuracy']
             )
history2 = model2.fit(x=x_train, y=y_train, 
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS, 
                    validation_data=(x_test, y_test), 
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Train on 24664 samples, validate on 2740 samples
# Epoch 1/25
# 24664/24664 [==============================] - 448s 18ms/sample - loss: 0.9331 - accuracy: 0.6397 - val_loss: 1.1481 - val_accuracy: 0.5825
# Epoch 2/25
# 24664/24664 [==============================] - 441s 18ms/sample - loss: 0.4018 - accuracy: 0.8668 - val_loss: 0.5411 - val_accuracy: 0.8336
# Epoch 3/25
# 24664/24664 [==============================] - 437s 18ms/sample - loss: 0.2534 - accuracy: 0.9177 - val_loss: 0.2475 - val_accuracy: 0.9354
# Epoch 4/25
# 24664/24664 [==============================] - 439s 18ms/sample - loss: 0.2561 - accuracy: 0.9214 - val_loss: 0.3903 - val_accuracy: 0.9026
# Epoch 5/25
# 24664/24664 [==============================] - 440s 18ms/sample - loss: 0.2173 - accuracy: 0.9333 - val_loss: 0.1635 - val_accuracy: 0.9438
# Epoch 6/25
# 24664/24664 [==============================] - 440s 18ms/sample - loss: 0.1834 - accuracy: 0.9411 - val_loss: 0.3561 - val_accuracy: 0.8672
# Epoch 7/25
# 24664/24664 [==============================] - 439s 18ms/sample - loss: 0.1735 - accuracy: 0.9466 - val_loss: 0.1603 - val_accuracy: 0.9504
# Epoch 8/25
# 24664/24664 [==============================] - 440s 18ms/sample - loss: 0.1661 - accuracy: 0.9453 - val_loss: 0.1832 - val_accuracy: 0.9507
# Epoch 9/25
# 24664/24664 [==============================] - 439s 18ms/sample - loss: 0.1556 - accuracy: 0.9505 - val_loss: 0.1618 - val_accuracy: 0.9460
# Epoch 10/25
# 24664/24664 [==============================] - 441s 18ms/sample - loss: 0.1470 - accuracy: 0.9515 - val_loss: 0.1471 - val_accuracy: 0.9507
# Epoch 11/25
# 24664/24664 [==============================] - 444s 18ms/sample - loss: 0.1335 - accuracy: 0.9548 - val_loss: 0.1503 - val_accuracy: 0.9536
# Epoch 12/25
# 24664/24664 [==============================] - 2555s 104ms/sample - loss: 0.1352 - accuracy: 0.9558 - val_loss: 0.1435 - val_accuracy: 0.9515
# Epoch 13/25
# 24664/24664 [==============================] - 442s 18ms/sample - loss: 0.1325 - accuracy: 0.9571 - val_loss: 0.1445 - val_accuracy: 0.9515
# Epoch 14/25
# 24664/24664 [==============================] - 445s 18ms/sample - loss: 0.1274 - accuracy: 0.9559 - val_loss: 0.1401 - val_accuracy: 0.9500
# Epoch 15/25
# 24664/24664 [==============================] - 456s 18ms/sample - loss: 0.1261 - accuracy: 0.9578 - val_loss: 0.1511 - val_accuracy: 0.9507
# Epoch 16/25
# 24664/24664 [==============================] - 443s 18ms/sample - loss: 0.1264 - accuracy: 0.9579 - val_loss: 0.1341 - val_accuracy: 0.9515
# Epoch 17/25
# 24664/24664 [==============================] - 442s 18ms/sample - loss: 0.1225 - accuracy: 0.9580 - val_loss: 0.1334 - val_accuracy: 0.9544
# Epoch 18/25
# 24664/24664 [==============================] - 444s 18ms/sample - loss: 0.1235 - accuracy: 0.9595 - val_loss: 0.1341 - val_accuracy: 0.9540
# Epoch 19/25
# 24664/24664 [==============================] - 446s 18ms/sample - loss: 0.1195 - accuracy: 0.9594 - val_loss: 0.1462 - val_accuracy: 0.9533
# Epoch 20/25
# 24664/24664 [==============================] - 448s 18ms/sample - loss: 0.1137 - accuracy: 0.9620 - val_loss: 0.1308 - val_accuracy: 0.9558
# Epoch 21/25
# 24664/24664 [==============================] - 437s 18ms/sample - loss: 0.1116 - accuracy: 0.9622 - val_loss: 0.1293 - val_accuracy: 0.9566
# Epoch 22/25
# 24664/24664 [==============================] - 440s 18ms/sample - loss: 0.1111 - accuracy: 0.9607 - val_loss: 0.1285 - val_accuracy: 0.9566
# Epoch 23/25
# 24664/24664 [==============================] - 445s 18ms/sample - loss: 0.1105 - accuracy: 0.9633 - val_loss: 0.1387 - val_accuracy: 0.9562
# Epoch 24/25
# 24664/24664 [==============================] - 444s 18ms/sample - loss: 0.1087 - accuracy: 0.9629 - val_loss: 0.1301 - val_accuracy: 0.9580
# Epoch 25/25
# 24664/24664 [==============================] - 445s 18ms/sample - loss: 0.1078 - accuracy: 0.9647 - val_loss: 0.1278 - val_accuracy: 0.9573

# %%
from sklearn.metrics import accuracy_score
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 10))
t = f.suptitle('CNN Performance on SGD optimizer', fontsize=16,fontweight='bold')
f.subplots_adjust(top=0.9, wspace=0.1)

max_epoch = len(history2.history['accuracy'])+1
epoch_list = list(range(1,max_epoch))
ax1.plot(epoch_list, history2.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history2.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(1, max_epoch, 1))
ax1.set_ylabel('Accuracy Value',fontsize=14,fontweight='bold')
ax1.set_xlabel('Epoch',fontsize=14,fontweight='bold')
ax1.set_title('Accuracy', fontsize=14,fontweight='bold')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history2.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history2.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(1, max_epoch, 1))
ax2.set_ylabel('Loss Value',fontsize=14,fontweight='bold')
ax2.set_xlabel('Epoch',fontsize=14,fontweight='bold')
ax2.set_title('Loss',fontsize=14,fontweight='bold')
l2 = ax2.legend(loc="best")

# %%
from sklearn.metrics import confusion_matrix
pred = model2.predict(x_test)
pred = np.argmax(pred,axis = 1) 
y_true = np.argmax(y_test,axis = 1)

# %%
# %%time
import mlxtend
CM = confusion_matrix(y_true, pred)
from mlxtend.plotting import plot_confusion_matrix
fig, ax = plot_confusion_matrix(conf_mat=CM ,  figsize=(5, 5))
plt.show()
# Out:
# CPU times: user 306 ms, sys: 34.3 ms, total: 340 ms
# Wall time: 200 ms

# %%
model2.save('models_app/my_model_sgd.h5')

# %%
plt.plot(history2.history['accuracy'])
plt.plot(history2.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Accuracy")
plt.ylabel("Epochs")
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
from sklearn.metrics import auc
fpr_keras, tpr_keras, thresholds = roc_curve(y_true.ravel(), pred.ravel())
auc_keras = auc(fpr_keras, tpr_keras)

# %%
def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color='orange', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()

# %%
plot_roc_curve(fpr_keras, tpr_keras)

# %%
from sklearn.metrics import classification_report

# %%
print('{}'.format(classification_report(y_true , pred)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96      1351
#            1       0.95      0.97      0.96      1389
#
#     accuracy                           0.96      2740
#    macro avg       0.96      0.96      0.96      2740
# weighted avg       0.96      0.96      0.96      2740

# %% [markdown]
# # Model 3 RMSPROP

# %%
#instantiate the model
height = 125
width = 125
classes = 2
channels = 3
model3 = CNNbuild(height = height, width = width, classes = classes, channels = channels)
model3.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 123, 123, 32)      896
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 61, 61, 32)        0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 61, 61, 32)        128
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 61, 61, 32)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 59, 59, 32)        9248
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 29, 29, 32)        0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 29, 29, 32)        128
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 29, 29, 32)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 27, 27, 32)        9248
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 13, 13, 32)        128
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 5408)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               2769408
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 2,792,258
# Trainable params: 2,791,042
# Non-trainable params: 1,216
# _________________________________________________________________

# %%
model3.compile(loss = 'categorical_crossentropy', optimizer = 'RMSprop', metrics = ['accuracy'])

history3 = model3.fit(x=x_train, y=y_train, 
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS, 
                    validation_data=(x_test, y_test), 
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Train on 24664 samples, validate on 2740 samples
# Epoch 1/25
# 24664/24664 [==============================] - 511s 21ms/sample - loss: 0.4874 - accuracy: 0.8054 - val_loss: 0.4934 - val_accuracy: 0.8595
# Epoch 2/25
# 24664/24664 [==============================] - 477s 19ms/sample - loss: 0.2169 - accuracy: 0.9240 - val_loss: 0.2336 - val_accuracy: 0.9124
# Epoch 3/25
# 24664/24664 [==============================] - 467s 19ms/sample - loss: 0.1767 - accuracy: 0.9396 - val_loss: 0.2148 - val_accuracy: 0.9212
# Epoch 4/25
# 24664/24664 [==============================] - 466s 19ms/sample - loss: 0.1649 - accuracy: 0.9469 - val_loss: 0.1636 - val_accuracy: 0.9493
# Epoch 5/25
# 24664/24664 [==============================] - 458s 19ms/sample - loss: 0.1574 - accuracy: 0.9497 - val_loss: 0.1973 - val_accuracy: 0.9274
# Epoch 6/25
# 24664/24664 [==============================] - 456s 18ms/sample - loss: 0.1533 - accuracy: 0.9500 - val_loss: 0.1529 - val_accuracy: 0.9511
# Epoch 7/25
# 24664/24664 [==============================] - 455s 18ms/sample - loss: 0.1471 - accuracy: 0.9515 - val_loss: 0.1767 - val_accuracy: 0.9551
# Epoch 8/25
# 24664/24664 [==============================] - 460s 19ms/sample - loss: 0.1431 - accuracy: 0.9539 - val_loss: 0.2984 - val_accuracy: 0.8909
# Epoch 9/25
# 24664/24664 [==============================] - 471s 19ms/sample - loss: 0.1307 - accuracy: 0.9565 - val_loss: 0.1453 - val_accuracy: 0.9515
# Epoch 10/25
# 24664/24664 [==============================] - 459s 19ms/sample - loss: 0.1191 - accuracy: 0.9606 - val_loss: 0.2130 - val_accuracy: 0.9310
# Epoch 11/25
# 24664/24664 [==============================] - 455s 18ms/sample - loss: 0.1223 - accuracy: 0.9610 - val_loss: 0.1660 - val_accuracy: 0.9511
# Epoch 12/25
# 24664/24664 [==============================] - 454s 18ms/sample - loss: 0.1182 - accuracy: 0.9612 - val_loss: 0.1847 - val_accuracy: 0.9496
# Epoch 13/25
# 24664/24664 [==============================] - 454s 18ms/sample - loss: 0.1147 - accuracy: 0.9619 - val_loss: 0.1411 - val_accuracy: 0.9540
# Epoch 14/25
# 24664/24664 [==============================] - 455s 18ms/sample - loss: 0.1082 - accuracy: 0.9645 - val_loss: 0.1504 - val_accuracy: 0.9536
# Epoch 15/25
# 24664/24664 [==============================] - 455s 18ms/sample - loss: 0.1109 - accuracy: 0.9645 - val_loss: 0.1849 - val_accuracy: 0.9383
# Epoch 16/25
# 24664/24664 [==============================] - 455s 18ms/sample - loss: 0.1129 - accuracy: 0.9629 - val_loss: 0.1488 - val_accuracy: 0.9529
# Epoch 17/25
# 24664/24664 [==============================] - 459s 19ms/sample - loss: 0.1045 - accuracy: 0.9659 - val_loss: 0.1513 - val_accuracy: 0.9500
# Epoch 18/25
# 24664/24664 [==============================] - 458s 19ms/sample - loss: 0.1035 - accuracy: 0.9661 - val_loss: 0.1370 - val_accuracy: 0.9588
# Epoch 19/25
# 24664/24664 [==============================] - 455s 18ms/sample - loss: 0.1025 - accuracy: 0.9670 - val_loss: 0.1495 - val_accuracy: 0.9536
# Epoch 20/25
# 24664/24664 [==============================] - 455s 18ms/sample - loss: 0.1034 - accuracy: 0.9667 - val_loss: 0.1521 - val_accuracy: 0.9562
# Epoch 21/25
# 24664/24664 [==============================] - 454s 18ms/sample - loss: 0.1034 - accuracy: 0.9663 - val_loss: 0.1453 - val_accuracy: 0.9529
# Epoch 22/25
# 24664/24664 [==============================] - 453s 18ms/sample - loss: 0.1012 - accuracy: 0.9663 - val_loss: 0.1462 - val_accuracy: 0.9540
# Epoch 23/25
# 24664/24664 [==============================] - 454s 18ms/sample - loss: 0.0930 - accuracy: 0.9689 - val_loss: 0.1574 - val_accuracy: 0.9529
# Epoch 24/25
# 24664/24664 [==============================] - 455s 18ms/sample - loss: 0.0906 - accuracy: 0.9706 - val_loss: 0.1527 - val_accuracy: 0.9555
# Epoch 25/25
# 24664/24664 [==============================] - 468s 19ms/sample - loss: 0.0967 - accuracy: 0.9684 - val_loss: 0.2089 - val_accuracy: 0.9372

# %%
from sklearn.metrics import accuracy_score
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 10))
t = f.suptitle(' CNN Performance for RMSProp', fontsize=16,fontweight='bold')
f.subplots_adjust(top=0.9, wspace=0.1)

max_epoch = len(history3.history['accuracy'])+1
epoch_list = list(range(1,max_epoch))
ax1.plot(epoch_list, history3.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history3.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(1, max_epoch, 1))
ax1.set_ylabel('Accuracy Value',fontsize=14,fontweight='bold')
ax1.set_xlabel('Epoch',fontsize=14,fontweight='bold')
ax1.set_title('Accuracy', fontsize=14,fontweight='bold')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history3.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history3.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(1, max_epoch, 1))
ax2.set_ylabel('Loss Value',fontsize=14,fontweight='bold')
ax2.set_xlabel('Epoch',fontsize=14,fontweight='bold')
ax2.set_title('Loss',fontsize=14,fontweight='bold')
l2 = ax2.legend(loc="best")

# %%
from sklearn.metrics import confusion_matrix
pred = model3.predict(x_test)
pred = np.argmax(pred,axis = 1) 
y_true = np.argmax(y_test,axis = 1)

# %%
# %%time
import mlxtend
CM = confusion_matrix(y_true, pred)
from mlxtend.plotting import plot_confusion_matrix
fig, ax = plot_confusion_matrix(conf_mat=CM ,  figsize=(5, 5))
plt.show()
# Out:
# CPU times: user 305 ms, sys: 29.9 ms, total: 335 ms
# Wall time: 199 ms

# %%
model3.save('models_app/my_model_RMSProp.h5')

# %%
plt.plot(history3.history['accuracy'])
plt.plot(history3.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Accuracy")
plt.ylabel("Epochs")
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
from sklearn.metrics import auc
fpr_keras, tpr_keras, thresholds = roc_curve(y_true.ravel(), pred.ravel())
auc_keras = auc(fpr_keras, tpr_keras)
auc_keras
# Out:
# 0.9366168249101138

# %%
def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color='orange', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()

# %%
plot_roc_curve(fpr_keras, tpr_keras)

# %%
from sklearn.metrics import classification_report

# %%
print('{}'.format(classification_report(y_true , pred)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93      1351
#            1       0.90      0.98      0.94      1389
#
#     accuracy                           0.94      2740
#    macro avg       0.94      0.94      0.94      2740
# weighted avg       0.94      0.94      0.94      2740

# %% [markdown]
# ### With Data augumentation

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1/255.,
                                  horizontal_flip = True,
                                  width_shift_range = 0.2,
                                  height_shift_range = 0.2,
                                  fill_mode = 'nearest',
                                  zoom_range = 0.3,
                                  rotation_range = 30)
val_datagen = ImageDataGenerator(rescale = 1/255.)

train_generator = train_datagen.flow(x_train, y_train, batch_size = 32, shuffle = False)
val_generator = val_datagen.flow(x_test, y_test, batch_size = 32, shuffle = False)

# %%
#calling the same model as above
model_aug = CNNbuild(height = height, width = width, classes = classes, channels = channels)

# %%
#compile the model
optim = optimizers.Adam(lr = 0.001, decay = 0.001 / 64)
model_aug.compile(loss = 'categorical_crossentropy', optimizer = optim, metrics = ['accuracy'])

# %%
# h_aug = model_aug.fit_generator(train_generator, steps_per_epoch = len(x_train) // 32, epochs = 25)

h_aug = model_aug.fit(x=x_train, y=y_train, 
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS, 
                    validation_data=(x_test, y_test), 
                    callbacks=callbacks,
                    verbose=1)
# Out:
# Train on 24664 samples, validate on 2740 samples
# Epoch 1/25
# 24664/24664 [==============================] - 464s 19ms/sample - loss: 0.1761 - accuracy: 0.9432 - val_loss: 0.1449 - val_accuracy: 0.9529
# Epoch 2/25
# 24664/24664 [==============================] - 455s 18ms/sample - loss: 0.1492 - accuracy: 0.9511 - val_loss: 0.1371 - val_accuracy: 0.9529
# Epoch 3/25
# 24664/24664 [==============================] - 454s 18ms/sample - loss: 0.1394 - accuracy: 0.9551 - val_loss: 0.1227 - val_accuracy: 0.9515
# Epoch 4/25
# 24664/24664 [==============================] - 454s 18ms/sample - loss: 0.1320 - accuracy: 0.9560 - val_loss: 0.1259 - val_accuracy: 0.9544
# Epoch 5/25
# 24664/24664 [==============================] - 460s 19ms/sample - loss: 0.1260 - accuracy: 0.9571 - val_loss: 0.1290 - val_accuracy: 0.9558
# Epoch 6/25
# 24664/24664 [==============================] - 458s 19ms/sample - loss: 0.1157 - accuracy: 0.9616 - val_loss: 0.1250 - val_accuracy: 0.9577
# Epoch 7/25
# 24664/24664 [==============================] - 459s 19ms/sample - loss: 0.1065 - accuracy: 0.9640 - val_loss: 0.1162 - val_accuracy: 0.9584
# Epoch 8/25
# 24664/24664 [==============================] - 453s 18ms/sample - loss: 0.1027 - accuracy: 0.9659 - val_loss: 0.1182 - val_accuracy: 0.9577
# Epoch 9/25
# 24664/24664 [==============================] - 454s 18ms/sample - loss: 0.0993 - accuracy: 0.9656 - val_loss: 0.1162 - val_accuracy: 0.9580
# Epoch 10/25
# 24664/24664 [==============================] - 454s 18ms/sample - loss: 0.0926 - accuracy: 0.9683 - val_loss: 0.1173 - val_accuracy: 0.9595
# Epoch 11/25
# 24664/24664 [==============================] - 452s 18ms/sample - loss: 0.0902 - accuracy: 0.9685 - val_loss: 0.1193 - val_accuracy: 0.9569
# Epoch 12/25
# 24664/24664 [==============================] - 452s 18ms/sample - loss: 0.0854 - accuracy: 0.9715 - val_loss: 0.1151 - val_accuracy: 0.9599
# Epoch 13/25
# 24664/24664 [==============================] - 459s 19ms/sample - loss: 0.0819 - accuracy: 0.9721 - val_loss: 0.1257 - val_accuracy: 0.9584
# Epoch 14/25
# 24664/24664 [==============================] - 450s 18ms/sample - loss: 0.0766 - accuracy: 0.9732 - val_loss: 0.1287 - val_accuracy: 0.9588
# Epoch 15/25
# 24664/24664 [==============================] - 451s 18ms/sample - loss: 0.0765 - accuracy: 0.9744 - val_loss: 0.1249 - val_accuracy: 0.9562
# Epoch 16/25
# 24664/24664 [==============================] - 450s 18ms/sample - loss: 0.0715 - accuracy: 0.9750 - val_loss: 0.1342 - val_accuracy: 0.9573
# Epoch 17/25
# 24664/24664 [==============================] - 453s 18ms/sample - loss: 0.0698 - accuracy: 0.9762 - val_loss: 0.1390 - val_accuracy: 0.9569
# Epoch 18/25
# 24664/24664 [==============================] - 449s 18ms/sample - loss: 0.0674 - accuracy: 0.9776 - val_loss: 0.1305 - val_accuracy: 0.9566
# Epoch 19/25
# 24664/24664 [==============================] - 447s 18ms/sample - loss: 0.0620 - accuracy: 0.9790 - val_loss: 0.1356 - val_accuracy: 0.9591
# Epoch 20/25
# 24664/24664 [==============================] - 449s 18ms/sample - loss: 0.0585 - accuracy: 0.9809 - val_loss: 0.1338 - val_accuracy: 0.9566
# Epoch 21/25
# 24664/24664 [==============================] - 470s 19ms/sample - loss: 0.0571 - accuracy: 0.9796 - val_loss: 0.1359 - val_accuracy: 0.9580
# Epoch 22/25
# 24664/24664 [==============================] - 467s 19ms/sample - loss: 0.0507 - accuracy: 0.9829 - val_loss: 0.1337 - val_accuracy: 0.9580
# Epoch 23/25
# 24664/24664 [==============================] - 458s 19ms/sample - loss: 0.0514 - accuracy: 0.9821 - val_loss: 0.1462 - val_accuracy: 0.9573
# Epoch 24/25
# 24664/24664 [==============================] - 480s 19ms/sample - loss: 0.0496 - accuracy: 0.9829 - val_loss: 0.1669 - val_accuracy: 0.9569
# Epoch 25/25
# 24664/24664 [==============================] - 466s 19ms/sample - loss: 0.0529 - accuracy: 0.9813 - val_loss: 0.1448 - val_accuracy: 0.9558

# %%
# # Loading tensorboard
# import tensorflow as tf
# from tensorflow.python.summary import summary_iterator
# import os
# log_base_dir = 'Desktop/tensorboard_logs'
# os.makedirs(log_base_dir,exist_ok = True)
# %tensorboard --logdir {log_base_dir}

# %%
# get predictions on the test set
y_hat = model_aug.predict(x_test)

malaria_labels = ['Parasitized','Uninfected']

# %%
x_test.shape[0]
# Out:
# 2740

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=12, replace=False)):
    ax = fig.add_subplot(4,4, i+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(malaria_labels[pred_idx], malaria_labels[true_idx]),
                 color=("blue" if pred_idx == true_idx else "red"))
